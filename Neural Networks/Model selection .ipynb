# %%
import numpy as np
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error
import tensorflow as tf
import matplotlib.pyplot as plt

# %%
data=np.array([[1651.  ,  432.65], [1691.82,  454.94],[1732.63,  471.53],[1773.45,  482.51],[1814.27,  468.36], [1855.08,  482.15], [1895.9 ,  540.02],[1936.71,  534.58],[1977.53,  558.35],[2018.35,  566.42],[2059.16,  581.4 ],[2099.98,  596.46],[2140.8 ,  596.71],[2181.61,  619.45],[2222.43,  616.58],[2263.24,  653.16],[2304.06,  666.52],[2344.88,  670.59],[2385.69,  669.02],[2426.51,  678.91],[2467.33,  707.44],
[2508.14,  710.76],[2548.96,  745.19],[2589.78,  729.85],[2630.59,  743.8 ],[2671.41,  738.2 ],[2712.22,  772.95],[2753.04,  772.22],[2793.86,  784.21],[2834.67,  776.43],[2875.49,  804.78],[2916.31,  833.27],[2957.12,  825.69],[2997.94,  821.05],[3038.76,  833.82],[3079.57,  833.06],[3120.39,  825.7 ],[3161.2 ,  843.58],[3202.02,  869.4 ],[3242.84,  851.5 ],[3283.65,  863.18],[3324.47,  853.01], [3365.29,  877.16],[3406.1 ,  863.74],[3446.92,  874.67],[3487.73,  877.74],[3528.55,  874.11],[3569.37,  882.8 ],[3610.18,  910.83],[3651.  ,  897.42]])

# %%
#Size of house 
x=data[:,0]

# %%
#price in $10000
y=data[:,1]

# %%
plt.scatter(x,y,color="red",marker="x")

# %%
#Split the data
x_train,x_,y_train,y_=train_test_split(x,y,test_size=0.40,random_state=1)
x_cv,x_test,y_cv,y_test=train_test_split(x_,y_,test_size=0.50,random_state=1)

# %%
del x_,y_

# %%
print(f"the shape of the training set (input) is: {x_train.shape}")
print(f"the shape of the training set (target) is: {y_train.shape}\n")
print(f"the shape of the cross validation set (input) is: {x_cv.shape}")
print(f"the shape of the cross validation set (target) is: {y_cv.shape}\n")
print(f"the shape of the test set (input) is: {x_test.shape}")
print(f"the shape of the test set (target) is: {y_test.shape}")
# Out:
# the shape of the training set (input) is: (30,)
# the shape of the training set (target) is: (30,)
#
# the shape of the cross validation set (input) is: (10,)
# the shape of the cross validation set (target) is: (10,)
#
# the shape of the test set (input) is: (10,)
# the shape of the test set (target) is: (10,)

# %%
plt.scatter(x_train,y_train,marker="x",label="Training_set")
plt.scatter(x_cv,y_cv,marker="^",label="Cross_validation")
plt.scatter(x_test,y_test,marker="o",label="Test_set")
plt.legend()

# %%
x_train=x_train.reshape(-1,1)

# %%
linear_scaler=StandardScaler()
x_train_scaled=linear_scaler.fit_transform(x_train)

# %%
linear_model=LinearRegression()
linear_model.fit(x_train_scaled,y_train)
# Out:
# LinearRegression()

# %%
y_hat=linear_model.predict(x_train_scaled)

# %%
mse=mean_squared_error(y_train,y_hat)/2

# %%
mse
# Out:
# 406.18142643101237

# %%
x_cv=x_cv.reshape(-1,1)

# %%
x_cv_scaled=linear_scaler.transform(x_cv)

# %%
x_cv_scaled
# Out:
# array([[ 1.07214863],
#        [ 0.43311619],
#        [-0.56092848],
#        [ 0.07810396],
#        [ 0.7171364 ],
#        [ 1.49817026],
#        [ 1.78217308],
#        [ 0.00709456],
#        [ 1.28515944],
#        [-1.27095292]])

# %%
yhat=linear_model.predict(x_cv_scaled)

# %%
mse2=mean_squared_error(y_cv,yhat)

# %%
mse2/2
# Out:
# 551.7633686764407

# %%
np.argmin(x)
# Out:
# 0
